# %% [markdown]
# # 05 — Text features
#
# **Goal:** Construct per-question complexity features so we can test whether the remaining questions got harder after ChatGPT.
#
# **Inputs:** Per-question sample from `sql/question_sample.sql` (not the monthly panel).
#
# **Outputs:**
# 1. Readability scores (Flesch, Flesch-Kincaid grade) per question.
# 2. Code-block count and total code length per question.
# 3. Composite difficulty score and its distribution per group, pre/post.
# 4. Save the question-level feature table to `data/processed/`.

# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.load import LLM_FRIENDLY, LLM_UNFRIENDLY, TREATMENT_DATE
from src.plots import setup_style, add_chatgpt_line, GROUP_COLORS
from src import features

setup_style()
print(f'Treatment date: {TREATMENT_DATE.date()}')

# %% [markdown]
# ## Readability

# %% [markdown]
# ## Code blocks

# %% [markdown]
# ## Composite difficulty score

# %% [markdown]
# ## Export to `data/processed/`
