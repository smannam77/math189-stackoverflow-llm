# %% [markdown]
# # 04 — Pre-trend check (parallel trends)
#
# **Goal:** Critical DiD diagnostic. If LLM-friendly and LLM-unfriendly groups were *already* trending apart before Dec 2022, the DiD estimate isn't a causal ChatGPT effect.
#
# **Outputs:**
# 1. Pre-period (Jan 2019 – Nov 2022) group means with linear fits.
# 2. Event-study plot: month-relative-to-treatment coefficients with 95% CIs; coefficients before t=0 should be ~0.
# 3. Formal pre-trend test (joint F-test on pre-period interaction terms).
# 4. Sensitivity: result with and without anomalous months (e.g. COVID spike Mar–Apr 2020).

# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.load import (
    load_monthly_panel, LLM_FRIENDLY, LLM_UNFRIENDLY, TREATMENT_DATE
)
from src.plots import setup_style, add_chatgpt_line, GROUP_COLORS

setup_style()
print(f'Treatment date: {TREATMENT_DATE.date()}')

# %% [markdown]
# ## Pre-period group means

# %% [markdown]
# ## Event-study plot

# %% [markdown]
# ## Formal pre-trend test

# %% [markdown]
# ## Sensitivity (excluding anomalous months)
